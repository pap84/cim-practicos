# %% [markdown]
# ### Curso de imágenes - Especialidad I (2018) - FAMAF-UNC
#
# **Alumna: L. Fischer**
#
# # Trabajo practico nº 7

# %%
# %matplotlib inline

from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

# %% [markdown]
# ## Ejercicio 1:
# Realizar una simulación determinista de la formación de la imagen por contraste de absorción de un cilindro de agua de 10 cm de diámetro y **altura** irradiado con un haz paralelo de fotones de 50 keV y tamaño de campo de 10 cm × 10 cm. (Detección ideal). Graficar perfil central de la imagen e interpretarlo en términos de las propiedades fı́sicas.
#
# *Elijo la altura del cilindro como 10 cm*

# %% [markdown]
# ****
# *Esto se puede ver en el plano X-Y siendo Z el que pasa por el eje del cilindro.*
# *Tengo un haz paralelo de energía fija que incide al eje Z. El círculo en el plano es de radio 5 cm.*
#
# El haz incidente con energía inicial $E_0 = 50 \ keV$ atenua su intensidad siguiendo la relación:
# $$  I = I_0  \ e^{- \mu \Delta x}  $$
# en mi caso $\Delta x$ es un valor fijo que tiene que ver con la distancia entre paso y paso. Así la atenuación será proporcional a la cantidad de veces que está dentro del cilindo:
# $$I_f = I_0 \ e^{- n \mu \Delta x}$$
# siendo n la candidad de pasos dentro del cilindro.
#
# El valor de $\mu$ para fotones de 50 keV se consigue de tabla y es:  $ \mu = 0.2269 \ cm^{-1} $
#
# *En mi caso tomo $\Delta x = 0.1 \ cm$*

# %%
#Datos del problema
E0= 50. 
I0=1.
mu= 0.2269
Delta_x = 0.1

N= 101 #y (ancho cilindo, equivale a 10 cm, Tiene que ser un valor impar)
M= 200 #x (hay detector)
matriz_espacio = np.zeros([N,M])  # para probar la primera vez tomo "pixeles de 0.1 cm"

#Resuelvo en un plano: creo el cilindo en la matriz

#Defino el cilindo < R=5
R = int(N/2.)

if 0==np.mod(N,2):
    N = N-1

if np.mod(M,2)==0:
    M = M-1

c=[int(N/2.),int(M/2.)]

#Funcion auxiliar: Norma Euclidea
def euclidea(imagen, x1, x2, y1, y2):
    DistanciaE = np.sqrt( (x1-x2)**2 + (y1-y2)**2)
    return DistanciaE

#Distacia ecuclidea:
for i in range(M):
    for j in range(N):
        dist = euclidea(matriz_espacio, c[1], i, c[0], j)
        if  R>= dist:
            matriz_espacio[j,i] = 1
        else:
            matriz_espacio[j,i] = 0

fig = plt.figure(figsize=(12,16))
plt.imshow(matriz_espacio, cmap='gray')
plt.title('Cilindro radio 5 cm')
plt.show()

# %%
#Pongo un detecto que sera un vector
vec_detect = np.zeros(N)
suma = np.zeros(N)

for j in range(N):
    suma[j] = np.sum(matriz_espacio[j,:])

vec_detect = I0* np.exp(- mu * suma * Delta_x)

#GRAFICO lo obtenido en el detector:

print(u'Coincida 0cm con el eje del cilindro, en el plano:')

ejex = np.arange(N)/10. - 5.

fig = plt.figure(figsize=(8,6))

p1= plt.plot(ejex, vec_detect)
p2=plt.plot([-5,5], [1,1], label= 'Intensidad inicial Io')
plt.xlabel(u'Detector perpedicular al haz [cm]') 
plt.ylabel(u'Intensidad [If/Io]')

plt.show()
# Out:
# Coincida 0cm con el eje del cilindro, en el plano:

# %%
#Hago imagen que mostraría el detector:

detector_50 = np.zeros((N,N))

for j in range(N):
    detector_50[j,:] = vec_detect

#Ya esta normalizado respecto de la Intensidad incidente, paso 1-->255:

detector_50 = detector_50*255.

fig_50keV = plt.figure(figsize=(12,10))
plt.imshow(detector_50, cmap='hot', vmin=0, vmax=255)

plt.xlabel(u'Eje x [cm]') 
plt.ylabel(u'Eje y [cm]')
plt.title(u'Imagen del detector, cilindo R=5cm')

plt.show()

# %% [markdown]
# ## Ejercicio 2:
# Repetir el ejercicio del item anterior para un haz incidente de 2 canales energéticos igualmente probables de 50 keV y 30 keV. Analizar y discutir los resultados obtenidos.
#
#
# El valor de $\mu$ para fotones de 50 keV se consigue de tabla y es:  $ \mu = 0.2269 \ cm^{-1} $
#
# El valor de $\mu$ para fotones de 30 keV se consigue de tabla y es:  $ \mu = 0.3756 \ cm^{-1} $
#
# *En mi caso tomo $\Delta x = 0.1 \ cm$*
#
# *Considero la intensidad inicial de ambos canales es la misma*

# %%
#Datos del problema
E0= 50. 
E1= 30.
I0=1.
mu0= 0.2269
mu1= 0.3756
Delta_x = 0.1

N= 101 #y (ancho cilindo, equivale a 10 cm, Tiene que ser un valor impar)
M= 200 #x (hay detector)
matriz_espacio = np.zeros([N,M])  # para probar la primera vez tomo "pixeles de 0.1 cm"

#ANALAGO AL EJERCICIO ANTERIOR RESUELVO EN EL PLANO, CREO EL CILINDRO.

#Defino el cilindo < R=5
R = int(N/2.)

if 0==np.mod(N,2):
    N = N-1

if np.mod(M,2)==0:
    M = M-1

c=[int(N/2.),int(M/2.)]

#Funcion auxiliar: Norma Euclidea
def euclidea(imagen, x1, x2, y1, y2):
    DistanciaE = np.sqrt( (x1-x2)**2 + (y1-y2)**2)
    return DistanciaE

#Distacia ecuclidea:
for i in range(M):
    for j in range(N):
        dist = euclidea(matriz_espacio, c[1], i, c[0], j)
        if  R>= dist:
            matriz_espacio[j,i] = 1
        else:
            matriz_espacio[j,i] = 0

# %%
#Pongo un detecto que sera un vector
vec_detector = np.zeros(N)
suma = np.zeros(N)

for j in range(N):
    suma[j] = np.sum(matriz_espacio[j,:])

for i in range(N):
    #Sorteo la posibilidad de que el haz sea de 50 keV o 30 keV:
    sorteo = np.random.rand()
    if sorteo <= 0.5:
        mu= mu0 #E= E0
    else:
        mu= mu1 #E= E1

    vec_detector[i] = I0* np.exp(- mu * suma[i] * Delta_x)


#Parametros para un gráfico auxiliar:
vec_aux30 = I0* np.exp(- mu1 * suma * Delta_x)
vec_aux50 = vec_detect

#GRAFICO lo obtenico en el detector:
print(u'Coincida 0cm con el eje del cilindro, en el plano:')

ejex = np.arange(N)/10. - 5.

fig1 = plt.figure(figsize=(10,8))

p1= plt.plot(ejex, vec_detector, 'ro', label='detectado')
p2=plt.plot([-5,5], [1,1], color='orange',label= 'Energía E0=50 keV')
p3= plt.plot(ejex, vec_aux50, 'b:' ,label='E= 50keV')
p4=plt.plot(ejex, vec_aux30, 'g:' ,label='E= 30keV')
plt.xlabel(u'detector perpedicular al haz [cm]') 
plt.ylabel(u'Intensidad [If/Io]')
plt.legend()
plt.title(u'Intensidad vs. canales energéticos')

fig2 = plt.figure(figsize=(10,8))

p1= plt.plot(ejex, vec_detector)
p2=plt.plot([-5,5], [1,1], color='orange',label= 'Intensidad inicial Io')
plt.xlabel(u'detector perpedicular al haz [cm]') 
plt.ylabel(u'Intensidad [If/Io]')
plt.title(u'Detección haz con doble canal E= 50/30 keV')


plt.show()
# Out:
# Coincida 0cm con el eje del cilindro, en el plano:

# %%
#Hago imagen que mostraría el detector:

detector = np.zeros((N,N))

for j in range(N):
    for i in range(N):
        #Sorteo la posibilidad de que el haz sea de 50 keV o 30 keV:
        sorteo = np.random.rand()
        if sorteo <= 0.5:
            mu= mu0 #E= E0
        else:
            mu= mu1 #E= E1
            
        vec_detector[i] = I0* np.exp(- mu * suma[i] * Delta_x)

    detector[j,:] = vec_detector


#Imagen de 30 keV (Extra)

detector_30 = np.zeros((N,N))

for j in range(N):
    detector_30[j,:] = vec_aux30

detector_30 = detector_30*255. #Paso a escala 255
    
#GRAFICO DEL DETECTOR

fig = plt.figure(figsize=(12,10))

detector = detector*255. #paso a escala 255

plt.imshow(detector, cmap='hot',  vmin=0, vmax=255)

plt.xlabel(u'Eje x [cm]') 
plt.ylabel(u'Eje y [cm]')
plt.title(u'Imagen del detector, cilindo R=5cm')


plt.show()

#Grafico auxiliar 50 y 30keV
fig_aux = plt.figure(figsize=(15,10))

ax1 = plt.subplot(121)
ax2 = plt.subplot(122)

ax1.imshow(detector_50, cmap='hot', vmin=0, vmax=255)
ax2.imshow(detector_30, cmap='hot', vmin=0, vmax=255)

ax1.set_title(u'Energía 50 kev', fontsize=14)
ax2.set_title(u'Energía 30 kev', fontsize=14)
plt.show()

# %% [markdown]
# **Conclusión:**
#
# *Es importante tener en cuenta que a diferentes energías el coeficiente de atenuación lineal varia. Como se esperaba cuando la energía del haz incidente es mayor el cilindro lo atenua menos.*
#
# *Realizar este proceso deterministico puede ser util para decidir con que energías irradiar una muestra que tiene un espesor dado. Ya que si se elije una energía muy baja al detector no llegara el haz y si es demasiado alta el detector se satura. (Para una Intensidad inicial fija)*

# %% [markdown]
# ## Ejercicio 3:
# Realizar una simulación Monte Carlo análoga al primer item. Analizar los
# resultados.

# %% [markdown]
# *************
# Voy a utilizar PENELOPE para hacer la simulación Monte Carlo. Hay 2 cambios a tener en cuenta:
#
# * El haz de energía no es puntual, es una fuente cuadrada de haces paralelos. Para generarla tengo que intervenir el archivo `penmain.f` que esta escrito en Fortran77.
# * Quiero los datos del detector, esto se puede lograr creando un detector real o virtual. Elijo la opción de crear un detector real. Tengo que elegir el material y tamaño y describirlo en la geometria,`geometria.geo`
#
# ### 1. Modificación de penmain.f
#
# A la hora de utilizar PENELOPE hay dos instancias, la primera donde se compila el ejecutable y luego cuando se lo ejecuta con todos los archivos: input, geometria, materiales.
#
# Para modificar penmain.f se lo debe hacer antes de la compilación del ejecutable interviniendo directamente el código de Fortran, es importante dejar comentados los detalles de la intervención. En este caso son 2 los cambios y se pueden ver en la siguiente imagen.
#
# 1. Se modifican las lineas de código que me definen el cuadrado de donde saldrá el haz, es decir el origen. Este está centrado en cero y como es de 10x10 (se encuentra en un Z determinado) lo elijo para: -5<X<5 ; -5<Y<5.
# 2. Se modifican los angulos con el cual sale cada uno de los haces del cuadrado esto asegura que sean angulos paralelos, para eso se definen los cosenos directores. Recordando que U,V,W corresponden a los asociados a X,Y,Z. Así como: $\phi = 0 $ y $\theta = \pi /2 $ tengo U,V=0 y W=1.
#
#
# *Hay que revisar bien el código al hacer las modificaciones ya que si se hacen antes de que se definan las variables el mismo código va a pisar los cambios realizados. Por eso hay que realizar cualqueir cambio una vez terminado el loop que esta relacionado a el valor a modificar.*

# %%
img_geo = Image.open('p7_intervencion.jpg')

fig, ax = plt.subplots(figsize=(20,16))
ax.imshow(img_geo)
ax.axes.xaxis.set_ticks([])
ax.axes.yaxis.set_ticks([])

plt.show()

# %% [markdown]
# ### 2. Archivo de geometria
#
# En el archivo `geometria.geo` voy a crear 2 geometrias:
#
# 1. Cilindro de radio 5 (diametro 10) cuyo eje se encuentra en el eje x [quiero que el haz se encuentre en el eje z].
# 2. Detector de telururo de cadmio (CdTe). Voy a elegir un detector de 10x10 y cuya profundidad sera de 1 cm, sé los detectores reales tienen láminas que son de unos milímetros nomas, decido sobreestimar el tamaño porque un detector no es solamente una lámina de material sensicle y en mi simulación puedo perder precisión si lo hago muy delgado (ya que muchos de los haces interactuarian y lo atravesarian). Elijo este material que se corresponde con el equipo que se tiene en el laboratorio. Sé en la lista de materiales de PENELOPE se corresponde con el número: 127 (Cadmium Telluride).
#
# *Recordar el agua corresponde con el número 278. Y que al tener dos geometrías con materiales distintos la primera se asocia al primer material listado y la segunda al segundo (salvo que yo lo defina de otro modo)*

# %%
img_geo = Image.open('p7_geometria.jpg')

fig, ax = plt.subplots(figsize=(14,14))
ax.imshow(img_geo)
ax.axes.xaxis.set_ticks([])
ax.axes.yaxis.set_ticks([])

plt.show()

# %% [markdown]
# ************
# ***************
# ## Resultados
#
# Grafico los resultados obtenidos utilizando el archivo generado: `3d-dose.dat` ya que me interesa hacer un mapeo de la dosis en el detector en 2D  (deposito de energía en el plano x-y). Esto se puede ver en la forma en que definí los bins en el input.
#
# *Respecto del archivo `3d-dose.dat`, (3D dose distribution)*
# * *columns 1 to 3: coordinates X,Y,Z of the bin centres*
# * *4th column: dose (eV/g).*
# * *5th column: statistical uncertainty (3 sigma).*
# * *columns 6 to 8: bin indices IX,IY,IZ.*
#
# *Es importante tener en claro que PENELOPE me devuelve información sobre la dosis, no sobre las energías. Se podría modificar el main del programa para que la información obtenida fuera la energía. Esto no se hizo ya que se puede ver que la dosis y la energía son proporcionales. Si bien los valores no son los mismos las relaciones se mantienen.*
#
# A la hora de crear el detector el único dato del archivo que me interesa es el valor de la dosis (columna 4). Es importante identificar en el plano 2D los datos que se encuentran en la tabla. Revisando el input puedo ver se fija el menor valor de X y se recorre de menor a mayor los valores de Y. Así sucesivamente y el último valor de la tabla corresponde a la dosis del punto X,Y = 4.95 (máximo valor que toman X e Y).

# %%
#Recordar en mi simulación x corresponde con el largo del cilindro (X= FILAS).
#Los valores de NBX y NBY coinciden con los que estan en el archivo ed-dose3.dat 

NBX = 101 # num de bins en X
NBY = 101 # num de bins en Y

detector = np.zeros((NBX,NBY))

data=np.loadtxt('3d-dose3.dat')  

dose = data[:,3]
N = 0 #me mueve dentro del vector dose

for i in range (NBX):
    for j in range (NBY):
        detector[i,j] = dose[N] 
        N = N+1
           
# Notar que la matriz la arme invertida con respecto al detector así que debería reflejar la imagen
# i.e, hacer un flip "top/bottom" . En este caso no es necesario por la simetría.
#Si quisiera hacerlo en el Practico 1 ejercicio 5 esta la forma general de flipear una matriz.
#Sino PIL trae un modulo para hacerlo.

# %%
fig = plt.figure(figsize=(12,10))

plt.imshow(detector, cmap='hot')  #Por default me toma el maximo valor de dosis como 255  

plt.xlabel(u'Eje x [cm]') 
plt.ylabel(u'Eje y [cm]')
plt.title(u'Imagen del detector, cilindo R=5cm, fotones de 50keV')
plt.show()

# %%
#Grafico comparacion
fig_comp = plt.figure(figsize=(15,10))

ax1 = plt.subplot(121)
ax2 = plt.subplot(122)

ax1.imshow(detector_50, cmap='hot')
ax2.imshow(detector, cmap='hot')

ax1.set_title(u'Deterministico', fontsize=14)
ax2.set_title(u'PENELOPE', fontsize=14)
plt.show()

# %% [markdown]
# *Puedo ver que con ambos métodos la figura que obtengo al final coincide. PENELOPE tiene en cuenta el scattering y por eso la imagen tiene más "ruido". El método deterministico es útil ocm oprimera aproximación para saber que esperar de una simulacion y ajustar los parametros acorde a ello.*

# %% [markdown]
# ## Ejercicio 4:
# Simular un set up experimental tı́pico del instrumento de laboratorio.

# %% [markdown]
# *El set up típico de laboratorio que armé es el que corresponde a la tesis*
